# %%
import random
POPULATION_SIZE = 100
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ 1234567890,.-;:_!"#%&/()=?@${[]}'''

# %%
TARGET = "K C Shekhar"

# %%
class individual(object):
    def __init__(self,chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(self):
        global GENES
        gene = random.choice(GENES)
        return gene
    
    @classmethod
    def create_gnome(self):
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]

    def mate(self,par2):
        child_chromosome = []
        for gp1,gp2 in zip(self.chromosome, par2.chromosome):
            prob = random.random()
            if prob < 0.45:
                T_gene = gp1
            elif prob < 0.9:
                T_gene = gp2
            else:
                T_gene = self.mutated_genes()
            child_chromosome.append(T_gene)
        return individual(child_chromosome)

    def cal_fitness(self):
        global TARGET
        fitness = 0
        for gs,gt in zip(self.chromosome,TARGET):
            if gs!=gt:
                fitness+=1
        return fitness

# %%
generation = 1
found = False
population = []
for _ in range(POPULATION_SIZE):
    gnome = individual.create_gnome()
    population.append(individual(gnome))

while not found:
    population = sorted(population, key= lambda x: x.fitness)
    if population[0].fitness <=0:
        found = True
        break
    new_generation = []
    s = int((10*POPULATION_SIZE)/100)
    new_generation.extend(population[:s])
    s = int((90*POPULATION_SIZE)/100)
    for _ in range(s):
        parent1 = random.choice(population[:50])
        parent2 = random.choice(population[:50])
        child = parent1.mate(parent2)

        new_generation.append(child)
        population = new_generation
    print(f"Generation : {generation}  \tString : {''.join(population[0].chromosome)}  \tFitness : {population[0].fitness}")
    generation += 1
print(f"Generation : {generation}  \tString : {''.join(population[0].chromosome)}  \tFitness : {population[0].fitness}")
# Out:
# Generation : 1  	String : k=/= hPRUTJ  	Fitness : 10
# Generation : 2  	String : K /  %;2E5#  	Fitness : 8
# Generation : 3  	String : K @ Bh;fH_U  	Fitness : 7
# Generation : 4  	String : K @ Bh;fH_U  	Fitness : 7
# Generation : 5  	String : KnC Bh;kE_U  	Fitness : 6
# Generation : 6  	String : K C [hwkEPU  	Fitness : 5
# Generation : 7  	String : K C [hwkEPU  	Fitness : 5
# Generation : 8  	String : K C [hwkEPU  	Fitness : 5
# Generation : 9  	String : K C [hwkEPU  	Fitness : 5
# Generation : 10  	String : K C [hwkEPU  	Fitness : 5
# Generation : 11  	String : K C Bh]kh8U  	Fitness : 4
# Generation : 12  	String : K C Bh]kh8U  	Fitness : 4
# Generation : 13  	String : K C Bh]kh8U  	Fitness : 4
# Generation : 14  	String : K C Bh]kh8U  	Fitness : 4
# Generation : 15  	String : K C Bhekh8#  	Fitness : 3
# Generation : 16  	String : K C Bhekh8#  	Fitness : 3
# Generation : 17  	String : K C Bhekh8#  	Fitness : 3
# Generation : 18  	String : K C Bhekh8#  	Fitness : 3
# Generation : 19  	String : K C Bhekh8#  	Fitness : 3
# Generation : 20  	String : K C Bhekh8#  	Fitness : 3
# Generation : 21  	String : K C Bhekh8#  	Fitness : 3
# Generation : 22  	String : K C Bhekh8#  	Fitness : 3
# Generation : 23  	String : K C Bhekh8#  	Fitness : 3
# Generation : 24  	String : K C Bhekh8#  	Fitness : 3
# Generation : 25  	String : K C Bhekh8#  	Fitness : 3
# Generation : 26  	String : K C Bhekh8#  	Fitness : 3
# Generation : 27  	String : K C Bhekh8#  	Fitness : 3
# Generation : 28  	String : K C yhekh8r  	Fitness : 2
# Generation : 29  	String : K C yhekh8r  	Fitness : 2
# Generation : 30  	String : K C yhekh8r  	Fitness : 2
# Generation : 31  	String : K C yhekh8r  	Fitness : 2
# Generation : 32  	String : K C yhekh8r  	Fitness : 2
# Generation : 33  	String : K C yhekh8r  	Fitness : 2
# Generation : 34  	String : K C yhekh8r  	Fitness : 2
